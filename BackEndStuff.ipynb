# %%
# Dependencies and Setup
import sqlite3
from flask import Flask, render_template, jsonify, redirect
import random
import pandas as pd
import numpy as np
import math


app = Flask(__name__)
app.debug=True

# Database Storage
br_db = sqlite3.connect('bitrate_db')
cursor = br_db.cursor()

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# def projectile_motion_range(initial_velocity,gravity,angle,horizontal_range):
#     """
#     Parameters
#     ==========
#     initial_velocity : float
#         initial_velocity of the projectile
#     gravity : float
#         gravity
#     angle : float
#
#     Results
#     =======
#     horizontal_range : float
#         horizontal_range
#     """
#     import numpy as np.sin()
#     horizontal_range = ((initial_velocity^2)(np.sin2(angle))/(gravity)
#     return horizontal_range

# %% [markdown]
# def projectile_motion_time(initial_velocity,gravity,angle,maximum_height):
#     """
#     Parameters
#     ==========
#     initial_velocity : float
#         initial_velocity of the projectile
#     gravity : float
#         gravity
#     angle : float
#
#     Results
#     =======
#     maximum_height : float
#         Range
#     """
#     import numpy as np
#     maximum_height = ((initial_velocity^2)(np.sin^2(angle))/(gravity)
#     return maximum_height

# %% [markdown]
# def projectile_motion_height(initial_velocity,gravity,angle,time_of_flight):
#     """
#     Parameters
#     ==========
#     initial_velocity : float
#         initial_velocity of the projectile
#     gravity : float
#     angle : float
#
#     Results
#     =======
#     time_flight : float
#         Range
#     """
#
#     import numpy as np
#     time_of_flight = (2(initial_velocity)(np.sin(angle))/(gravity)
#     return time_of_flight

# %% [markdown]
# def horizontal_velocity(Initial_Velocity, Initial_Angle):
#     """
#     Parameters
#     ==========
#     Initial_Velocity : float
#         Horizontal Velocity of the projectile
#
#     Results
#     =======
#     Horizontal Velocity : float
#         Horizontal Velocity of the projectile
#     """
#
#     import numpy as np
#     import math
#     math.pi
#     horizontal_velocity = (Initial_Velocity*2)[cos(Initial_Angle*/180)]
#     return horizontal_velocity

# %% [markdown]
# def vertical_velocity(Initial_Velocity,Initial_Angle,vertical_velocity):
#     """
#     Parameters
#     ==========
#     Vertical Velocity : float
#         Vertical Velocity of the projectile
#
#     Results
#     =======
#     Vertical Velocity : float
#         Vertical Velocity of the projectile
#     """
#     import numpy as np
#     vertical_velocity = (Initial_Velocity*2)[sin()/180]
#     return vertical_velocity

# %% [markdown]
# def free_fall_time(acceleration_due_to_gravity,vertical_velocity,free_fall_time):
#     """
#     Parameters
#     ==========
#     acceleration_due_to_gravity : float
#
#     Results
#     =======
#     Free Fall time : float
#         Free Fall time of the projectile
#     """
#
#     acceleration_due_to_gravity = 9.8
#     free_fall_time = vertical_velocity/acceleration_due_to_gravity
#     return free_fall_time

# %% [markdown]
# def total_time(Free_fall_time,Total time):
#     """
#     Parameters
#     ==========
#     Free_fall_time : float
#
#     Results
#     =======
#     Total time : float
#         total time of the projectile
#     """
#
#     total_time
#     total_time = 2*free_fall_time
#     return total_time

# %% [markdown]
# def Maximum_Height(vertical_velocity,Maximum_Height):
#     """
#     Parameters
#     ==========
#     maximum : float
#
#     Results
#     =======
#     Maximum_Height = float
#         Maximum of the projectile
#     """
#
#     Maximum_Height = (vertical_velocity*2)/(2*Acceleration_due_to_gravity)
#     return Maximum_Height

# %% [markdown]
# def Range(Horizontal_Velocity,Total_time):
#     """
#     Parameters
#     ==========
#     maximum : float
#
#     Results
#     =======
#     Range = float
#         Range of the projectile
#     """
#
#     Range = (Horizontal_Velocity*Total_Time)
#     return Range

# %%
values = [[3.0,4],[6.0,9],[10.0,15]]
last_values = [0,0]
last_velocity = 0
delta = 0.1  # Will need to play with this value.
terminal_velocity = None
for pos, time in values:
    velocity = (pos - last_values[0]) / (time - last_values[1])
    if abs(velocity - last_velocity) < delta:
        terminal_velocity = velocity
        break
    last_values = [pos, time]
    last_velocity = velocity
print ('Terminal Velocity:', terminal_velocity)
# Out:
# Terminal Velocity: 0.6666666666666666

# %%
#for pos, time in values:
#    velocity = (pos - last_values[0] / (time - last_values[1]))
#    if abs(velocity - last_velocity < delta:
#          terminal_velocity = velocity
#          break
#    last_values = []
#    last_velocity = velocity
#print ())

# %%
# Calculations
angle = [random.randint(1, 90) for k in range(1000)]
velocity = [random.randint(0, 100) for k in range(1000)]
velocity = np.array(velocity)
angle = np.array(angle)
gravity = 9.8
horizontal_velocity = velocity * (np.cos(angle*math.pi)/180)
vertical_velocity =  velocity * (np.sin(angle*math.pi)/180)
free_fall_time = (vertical_velocity/9.8)
total_time = (2*free_fall_time)
maximum_height = (2*vertical_velocity/(2*gravity))
#Range = (horizontal_velocity*total_time)

Range = ((velocity**2)*(np.sin(2*angle))/9.8)
# print(Range)


Range = ((velocity**2)*(np.sin(2*angle*3.14/180))/9.8)
print(Range)
# Out:
# [  3.42903487e+02   1.47984260e+02   6.16841072e+01   2.39066703e+01
#    9.96204952e+01   9.22051052e+01   2.94311871e+02   9.58653679e+00
#    4.96966067e+02   1.29573703e+02   6.49541437e+02   3.56454048e+01
#    8.48195237e-02   5.52828631e+00   3.46031035e-01   1.69461534e+01
#    1.97117863e+01   2.29398854e+00   7.57907158e+01   4.08045548e+01
#    4.69293688e+02   3.74392583e+02   5.68113083e+01   6.80490702e+02
#    1.32339662e+02   3.80529651e+02   5.99704281e+01   9.13371041e+01
#    2.04968877e+02   6.89093742e+00   1.25592215e+02   1.23469349e+01
#    6.15252179e+01   2.14374568e+00   1.61078207e+02   3.61874322e+01
#    3.38874207e+02   1.75178212e+02   9.79864756e+01   1.85391660e+01
#    6.90124086e+00   7.52496756e+01   3.01703463e+02   1.91865903e+02
#    1.62858887e+00   1.25174607e+02   1.05935826e+01   1.95395687e+02
#    3.55203969e+02   4.97254072e+02   1.01060038e-01   4.89034034e+02
#    6.28996131e+02   1.64084769e+01   2.48313047e-02   2.97070199e+01
# ...

# %%
# Creating the dataframe
moo=pd.DataFrame({'Angle': angle,
                  'Velocity': velocity,
                  'Horizontal Velocity': horizontal_velocity,
                  'Vertical Velocity': vertical_velocity,
                  'Free Fall Time': free_fall_time,
                  'Total Time': total_time,
                  'Maximum Height': maximum_height,
                  'Range': Range
                 },
#                columns=['Angle','Velocity','Gravity']
                )
# Data Munging

# Display the dataframe
moo.head(20)
# Out:
#     Angle  Free Fall Time  Horizontal Velocity  Maximum Height       Range  \
# 0      15    2.505409e-16            -0.455556    2.505409e-16  342.903487
# 1      85    3.537230e-16            -0.505556    3.537230e-16  147.984260
# 2       7    2.429855e-17            -0.277778    2.429855e-17   61.684107
# 3      87    7.571688e-16            -0.261111    7.571688e-16   23.906670
# 4       5    2.603416e-17            -0.416667    2.603416e-17   99.620495
# 5       3    1.936941e-17            -0.516667    1.936941e-17   92.205105
# 6      20   -9.302873e-17             0.372222   -9.302873e-17  294.311871
# 7      35    4.443865e-17            -0.055556    4.443865e-17    9.586537
# 8      35    3.199583e-16            -0.400000    3.199583e-16  496.966067
# 9      56   -1.438474e-16             0.205556   -1.438474e-16  129.573703
# 10     48   -2.665898e-16             0.444444   -2.665898e-16  649.541437
# ...

# %%
np.array(velocity) * 3.14
# Out:
# array([ 257.48,  285.74,  157.  ,  147.58,  235.5 ,  292.02,  210.38,
#          31.4 ,  226.08,  116.18,  251.2 ,  128.74,    6.28,   28.26,
#           6.28,  216.66,  135.02,   15.7 ,  106.76,  150.72,  213.52,
#         298.3 ,  229.22,  307.72,  248.06,  194.68,  204.1 ,  178.98,
#         163.28,  138.16,  166.42,   34.54,  100.48,   75.36,  182.12,
#         141.3 ,  263.76,  141.3 ,  166.42,   43.96,   34.54,  100.48,
#         292.02,  182.12,   12.56,  222.94,   43.96,  207.24,  185.26,
#         226.08,    3.14,  244.92,  301.44,  106.76,    3.14,   56.52,
#          75.36,  292.02,  298.3 ,  122.46,  276.32,  191.54,  125.6 ,
#         194.68,   18.84,  292.02,  229.22,  298.3 ,  191.54,  238.64,
#         304.58,  235.5 ,   28.26,  298.3 ,  188.4 ,  213.52,  298.3 ,
#          72.22,  216.66,  266.9 ,   31.4 ,  304.58,  178.98,   78.5 ,
#          34.54,   50.24,  182.12,  185.26,  109.9 ,  119.32,   31.4 ,
# ...

# %%
# Force a 'pattern' in the results columns
moo['Result'] = np.where((moo['Range']>=300) & (moo['Range']<=310), 1, 0)
moo.to_json('json.json', orient='records')

# %%
# Sort Values
moo = moo.sort_values('Result', ascending=False)
moo.head()
# Out:
#      Angle  Free Fall Time  Horizontal Velocity  Maximum Height       Range  \
# 991     61    1.310319e-16            -0.327778    1.310319e-16  301.433157
# 63      65    6.543863e-16            -0.344444    6.543863e-16  300.766838
# 806     27    2.371966e-16            -0.338889    2.371966e-16  307.072131
# 971     76   -1.066584e-15             0.444444   -1.066584e-15  307.368895
# 42      10   -6.456471e-17             0.516667   -6.456471e-17  301.703463
#
#        Total Time  Velocity  Vertical Velocity  Result
# 991  2.620638e-16        59       1.284113e-15       1
# 63   1.308773e-15        62       6.412986e-15       1
# 806  4.743933e-16        61       2.324527e-15       1
# 971 -2.133167e-15        80      -1.045252e-14       1
# 42  -1.291294e-16        93      -6.327342e-16       1

# %%
# Jsonify the Output
Test = pd.read_json('json.json')
Test['Result']
Labels = Test['Result'].values
Data = test[['Angle','Velocity']].values

# %%
# Machine learning model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state=1, stratify= labels)

# Model for LogisticRegression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
classifier.score(X_train, y_train)
classifier.score(X_test, y_test)
# Out:
# 0.96399999999999997

# %%
# 
classifier.predict([65, 30])
# Out:
# C:\Users\Abe\Anaconda2\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([0], dtype=int64)

# %%
#
classifier.predict([[12121, 23], [65, 30]])
# Out:
# array([1, 0], dtype=int64)

# %%
#
newSimulation = [[12121, 23], [65, 30]]

# %%
#
success_guesses = classifier.predict([[12121, 23], [65, 30]])

# %%
#
newSimulation
# Out:
# [[12121, 23], [65, 30]]

# %%
#
success_guesses
# Out:
# array([1, 0], dtype=int64)

# %%
#
for num in success_guesses:
    if (num == 1):
        print(num)
        print(newSimulation[num])
# Out:
# 1
# [65, 30]

# %%
# 
for x in range(len(success_guesses)):
    if (success_guesses[x] == 1):
        print(success_guesses[x])
        print(newSimulation[x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-df159ced91b3> in <module>()
# ----> 1 for x in range(len(success_guesses)):
#       2     if (success_guesses[x] == 1):
#       3         print(success_guesses[x])
#       4         print(newSimulation[x])
#
# NameError: name 'success_guesses' is not defined

# %%
#API Infrastructure
@app.route("/")
def home():
    return ("Hi!")

# %%
#API Infrastructure
@app.route("/practice", methods=["GET", "POST"])
def practice():

    # Initial Data
    practiceData = []
    
# Convert to DataFrame
practiceDF = pd.DataFrame(practiceData)

# Separate "Labels" and "Data"
labels = practiceDF["Success_Failure"].values
data = practiceDF[["Angle", "Velocity"]].values

# Create a Logistic Model 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state=1, stratify=labels)

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

classifier.fit(X_train, y_train)

# Score the Model
train_score = classifier.score(X_train, y_train)
test_score = classifier.score(X_test, y_test)

# Pickle 
pickle.dump(classifier, open("Classifier.sav", 'wb'))

# Return the Data
return(str(train_score))

# Route for Filtering JSONs
@app.route("/replay", methods=["GET", "POST"])
def replay(): 

    # Replay Data
    replayData = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-19169b028f54> in <module>()
#       1 # Convert to DataFrame
# ----> 2 practiceDF = pd.DataFrame(practiceData)
#       3
#       4 # Separate "Labels" and "Data"
#       5 labels = practiceDF["Success_Failure"].values
#
# NameError: name 'practiceData' is not defined

# %%
#def drop_table():
cursor.execute('DROP TABLE Kikoken')

# %%
# Filtered List
filteredData = []

# Reload the classifier
classifier = pickle.load(open("Classifier.sav", 'rb'))

# Filter it down using the Classifier
for x in range(len(replayData)):

print(replayData[x])
if(classifier.predict([replayData[x]["Angle"], replayData[x]["Velocity"]]) == 1):
    filteredData.append(replayData[x])

print(len(replayData))
print(len(filteredData))

# Display only filtered Data
return(jsonify(filteredData))

#################################################
# Flask Boilerplate
#################################################
if __name__ == '__main__':
    app.run(debug=True)
