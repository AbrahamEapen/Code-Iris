# %%
import sqlite3
from flask import Flask, render_template, jsonify, redirect
import random
import pandas as pd

app = Flask(__name__)
app.debug=True


br_db = sqlite3.connect('bitrate_db')
cursor = br_db.cursor()
# cursor.execute('CREATE TABLE bitrate(Velocity INTEGER, Angle INTEGER, Result TEXT, MSE INTEGER )')
# br_db.commit()

# br_db.commit()
# br_db.close()

# %%
def machine_learning():
    angle_list = [random.randint(1, 90) for k in range(100)]
    velocity_list = [random.uniform(0, 1) for k in range(100)]
    moo=pd.DataFrame({'Angles' : angle_list,'Velocity' : velocity_list,}, columns=['Angles','Velocity', 'Result','MSE'])
    moo.to_sql("Kikoken", br_db, if_exists="append")
    moo.head(10)
#pass these to the back end
def store_data():
#retrieve data(S/F batch), store to corresponding , and update ML alg
# Out:
#   File "<ipython-input-108-c6eb385accb3>", line 9
#     #retrieve data(S/F batch), store to corresponding , and update ML alg
#                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
# def no_machine_learning():
#     angle_list = [random.randint(1, 90) for k in range(100)]
#     velocity_list = [random.uniform(0, 1) for k in range(100)]
    
angle_list = [random.randint(1, 90) for k in range(1000)]
velocity_list = [random.uniform(0, 20) for k in range(1000)]
success_failure=[random.randint(0, 1) for k in range(1000)]
moo=pd.DataFrame({'Angles' : angle_list,'Velocity' : velocity_list,'Success_Failure' : success_failure,}, columns=['Angles','Velocity', 'Result','MSE'])

moo
value = [0]
target = []
if value[0] in target and (value[1] in target or value [1] target):

moo['Angles']>=45 

#Pass these to the front end
# Out:
#   File "<ipython-input-106-9cd5507f1a1e>", line 13
#     if value[0] in target and (value[1] in target or value [1] target):
#                                                                     ^
# SyntaxError: invalid syntax

# %%
moo[moo["Angle"] >45]["Success_Failure"]
# Out:
# 1

# %%
# def drop_table():

cursor.execute('DROP TABLE Kikoken')

# %%
angle_list = [random.randint(1, 90) for k in range(1000)]
velocity_list = [random.randint(0, 30) for k in range(1000)]
success_failure=[random.randint(0, 1) for k in range(1000)]
moo=pd.DataFrame({'Angle' : angle_list,'Velocity' : velocity_list,'Success_Failure' : success_failure}, columns=['Angle','Velocity','Success_Failure'])

# %%
moo.to_csv('test.csv', header=['angle','velocity','Success_Failure'])

# %%
moo.to_json('json4.json', orient='records')

# %%
test=pd.read_json('json2.json')

# %%
test['Success_Failure']

labels=test['Success_Failure'].values

# %%
data = test[['Angle','Velocity']].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state=1, stratify= labels)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.score(X_train, y_train)
# Out:
# 0.51733333333333331

# %%
classifier.score(X_test, y_test)
# Out:
# 0.49199999999999999

# %%
classifier.predict([65, 30])
# Out:
# /Users/michaelcavellero/anaconda/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([1])

# %%
classifier.predict([[12121, 23], [65, 30]])
# Out:
# <class 'numpy.ndarray'>

# %%
newSimulation = [[12121, 23], [65, 30]]

# %%
success_guesses = classifier.predict([[12121, 23], [65, 30]])

# %%
newSimulation
# Out:
# [[12121, 23], [65, 30]]

# %%
success_guesses
# Out:
# array([0, 1])

# %%
for num in success_guesses:
    if (num == 1):
        print(num)
        print(newSimulation[num])
# Out:
# 1
# [65, 30]

# %%
for x in range(len(success_guesses)):
    if (success_guesses[x] == 1):
        print(success_guesses[x])
        print(newSimulation[x])
# Out:
# 1
# [65, 30]

# %%
import _pickle as cPickle

# %%
stuff= pd.read_csv("test.csv")

# %%
stuff = stuff[["angle", "velocity", "Success_Failure"]]

# %%
newStuff = stuff[stuff["angle"] > 45]

# %%
newStuff["Success_Failure"] = 1
# Out:
# /Users/michaelcavellero/anaconda/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
newStuff.head()
# Out:
#    angle  velocity  Success_Failure
# 0     77        27                1
# 1     48        12                1
# 2     62        12                1
# 3     60         0                1
# 6     67        18                1

# %%
stuff["Success_Failure"] = stuff["angle"] > 45

# %%
stuff
# Out:
#      angle  velocity  Success_Failure
# 0       77        27             True
# 1       48        12             True
# 2       62        12             True
# 3       60         0             True
# 4       41        24            False
# 5       32        16            False
# 6       67        18             True
# 7       19        20            False
# 8       78        19             True
# 9       72         5             True
# 10      68         0             True
# 11       2        20            False
# 12      36        15            False
# 13      16        17            False
# 14       2        14            False
# 15       2        19            False
# 16      85        20             True
# 17      16        25            False
# 18       7        15            False
# 19      29        21            False
# 20       1         1            False
# 21      54        24             True
# 22      58        11             True
# 23       4         7            False
# ...

# %%
stuff["Success_Failure"].replace("True", 1, inplace=True)

# %%
stuff
# Out:
#      angle  velocity  Success_Failure
# 0       77        27             True
# 1       48        12             True
# 2       62        12             True
# 3       60         0             True
# 4       41        24            False
# 5       32        16            False
# 6       67        18             True
# 7       19        20            False
# 8       78        19             True
# 9       72         5             True
# 10      68         0             True
# 11       2        20            False
# 12      36        15            False
# 13      16        17            False
# 14       2        14            False
# 15       2        19            False
# 16      85        20             True
# 17      16        25            False
# 18       7        15            False
# 19      29        21            False
# 20       1         1            False
# 21      54        24             True
# 22      58        11             True
# 23       4         7            False
# ...

# %%
stuff["Success_Falure"] = (stuff["angle"] > 45) or (stuff["velocity"] < 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-866975675974> in <module>()
# ----> 1 (stuff["angle"] > 45) or (stuff["velocity"] < 20)
#
# /Users/michaelcavellero/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     953         raise ValueError("The truth value of a {0} is ambiguous. "
#     954                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 955                          .format(self.__class__.__name__))
#     956
#     957     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stuff.loc[(stuff["angle"]>45), "Success_Failure"] =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-bf32e1f84e3f> in <module>()
# ----> 1 stuff = stuff.loc[(stuff["angle"]>45), "Success_Failure"] = 1
#
# AttributeError: 'int' object has no attribute 'loc'

# %%
import numpy as np

stuff['Success_Failure']= np.where(stuff['angle']>50,1,0)
stuff
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-606e24e81ceb> in <module>()
#       1 import numpy as np
#       2
# ----> 3 stuff['Success_Failure']= np.where(stuff['angle']>50,1,0)
#       4 stuff
#
# TypeError: 'int' object is not subscriptable
